# %%
ls -l testdataset
# Out:
# total 61048
# -rw-r--r--@ 1 yehua  staff  31254665 Nov  9 09:50 usersGPS_test_serverData2.txt

# %%
#latest version! 
#f1 = open("data_serverFormat.txt")
f2 = open("./testdataset/usersGPS_test_serverData2.txt")
results = []
counter = 0
for line in f2:
    line = line.rstrip('\n')
    line = line.replace(" ","") #remove all white spaces!
    whole = line.split('{', 1)
    temp = whole[1].replace("}", '}, ')
    temp = temp.replace(':', ':[')
    temp = temp.replace("}", ']}')
    temp = temp.replace('{', r'{\"')
    temp = temp.replace(':', r'\":')
    friends = '"friends": "{\\"' + temp + '"'
    if counter == 87587 :
        l = '{"node" : "' + whole[0] + '", ' + friends +' } '
    else : 
        l = '{"node" : "' + whole[0] + '", ' + friends +' },  '
    if (counter == 0):
        print (l)
        print ("")
        print (l)
    results.append(l)
    counter +=1
print (counter)
# Out:
# {"node" : "0", "friends": "{\"1\":[329,0.00]}, {\"2\":[445,0.01]}, {\"3\":[1750,0.00]}, {\"4\":[1035,0.00]}, {\"5\":[11,0.04]}, {\"6\":[714,0.00]}, {\"7\":[394,0.00]}, {\"8\":[3351,0.00]}, {\"9\":[154,0.00]}, {\"10\":[208,0.00]}, {\"11\":[17,0.01]}, {\"12\":[582,0.00]}, {\"13\":[40,0.00]}, {\"14\":[51,0.00]}, {\"15\":[417,0.00]}, {\"16\":[408,0.00]}, {\"17\":[462,0.00]}, {\"18\":[52,0.01]}, {\"19\":[567,0.00]}, {\"20\":[77,0.00]}, {\"21\":[455,0.00]}, {\"22\":[10,0.00]}, {\"23\":[555,0.00]}, {\"24\":[3,0.00]}, {\"30609\":[11,0.00]}, " },
#
# ...

# %%
with open('./te_instagram.json', 'w') as f:
    for line in results:
        f.write("%s\n" % str(line))

# %%
#latest version! 
#f1 = open("data_serverFormat.txt")
f2 = open("./te_instagram.json")
results = []
counter = 0
for line in f2:
    line = line.rstrip('\n')
    line = line.replace(" ","") #remove all white spaces!
    whole = line.split('{', 1)
    temp = whole[1].replace("}", '}, ')
    temp = temp.replace(':', ':[')
    temp = temp.replace("}", ']}')
    temp = temp.replace('{', r'{\"')
    temp = temp.replace(':', r'\":')
    friends = '"friends": "{\\"' + temp + '"'
    if counter == 47709 :
        l = '{"node" : "' + whole[0] + '", ' + friends +' } '
    else : 
        l = '{"node" : "' + whole[0] + '", ' + friends +' },  '
    if (counter == 0):
        print (l)
        print ("")
        print (l)
    results.append(l)
    counter +=1
print (counter)

# %%
with open('./te2_instagram.json', 'w') as f:
    counter = 0
    for line in results:
        if (counter >= 48267):
            f.write("%s\n" % str(line))
        counter+=1

# %%
#uni process
#new version! 
re = []
f2 = open("uni_train.csv")

counter = 0
for line in f2:

    results = []
    #print (line)
    line = line.rstrip('\n')
    line = line.split(",")
    l = '{"uni" : "' + line[1] + '", "testcaseID" : "' + line[2] + '", "nOfSubmission" : "' + line[3] + '", "path" : "' + line[4] + '", "nOfQueries" : "' + line[5] + '" },'
    print (l)
    re.append(l)
    #print (line)
print (re)
print (len(re))
# Out:
# {"uni" : "hs2761", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# {"uni" : "it2216", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# {"uni" : "maa2247", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# {"uni" : "cy2415", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# {"uni" : "son2105", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# {"uni" : "jjs2238", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# {"uni" : "pb2616", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# {"uni" : "wjr2113", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# {"uni" : "jse2122", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },
# ...

# %%
with open('./uni_train.json', 'w') as f:
    for line in re:
        f.write("%s\n" % str(line))

# %% [markdown]
# processing 40 testcase and uni

# %%
#uni process
#new version! 
res = []
f3 = open("new_uni.csv")

counter = 0
for line in f3:

    #print (line)
    line = line.rstrip('\n')
    line = line.split(",")
    l = '{"uni" : "' + line[1] + '", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },'
    #print (l)
    res.append(l)
    counter += 1
    #print (line)
print (res)
print (len(res))
# Out:
# ['{"uni" : "brain", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "smile", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "pineapple", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "goat", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "cell", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "stomach", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "drink", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "yoga", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "goodness", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "grapes", "testcaseID" : "1", "nOfSubmission" : "0", "
# ...

# %%
#uni process
#new version! 
for i in range(2,41):
    f4 = open("new_uni.csv")

    counter = 0
    for line in f4:
        
        #print (line)
        line = line.rstrip('\n')
        line = line.split(",")
        l = '{"uni" : "' + line[1] + '", "testcaseID" : "'+str(i) +'", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },'
        #print (l)
        res.append(l)
        counter += 1
        #print (line)
print (res)
print (len(res))
# Out:
# ['{"uni" : "brain", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "smile", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "pineapple", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "goat", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "cell", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "stomach", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "drink", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "yoga", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "goodness", "testcaseID" : "1", "nOfSubmission" : "0", "path" : "null", "nOfQueries" : "0" },', '{"uni" : "grapes", "testcaseID" : "1", "nOfSubmission" : "0", "
# ...

# %%
with open('./uni_test.json', 'w') as f:
    for line in res:
        f.write("%s\n" % str(line))
